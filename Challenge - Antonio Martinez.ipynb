# %%
# 9x9 size labyrinth creation:
labyrinth = [['.', '.', '.','.','.','.','.','.','.'],
             ['.', '.', '.','.','.','.','.','.','.'],
             ['.', '.', '.','.','.','.','.','.','.'],
             ['.', '.', '.','.','.','.','.','.','.'],
             ['.', '.', '.','.','.','.','.','.','.']]

# 1x3 size rod creation:
rod = ['=','=','=']

# Places the rod in the start position, upper-left corner
def startRod():    
    for i in range(len(rod)):
        labyrinth[0][i] = rod[i] #places the rod in the specified position
    print(*labyrinth, sep = "\n", end = "\n\n") #shows the labyrinth
        
# Set the labyrinth to the starting point by replacing all "=" with "."
def resetLab():  
    for i in range(len(labyrinth)):
        for j in range (0,9):           
            if labyrinth[i][j] == '=':
                labyrinth[i][j] == '.'
    print(*labyrinth, sep = "\n", end = "\n\n") #shows the labyrinth after reseting the rod

# Returns the current position of the rod
def currentPosition():
    position = []
    for i in range(len(labyrinth)):
        for j in range (0,9):           
            if labyrinth[i][j] == '=':
                position.append([i,j])    
    print (position) ##Quitar una vez terminado
    return position 

# Public moveRight() function:
def moveRight():
    if (orientationHor()== True):
        _moveRightHor()
    else:
        _moveRightVer()

# private function: Move rod to the right if its orientation is horizontal, orientation = True
def _moveRightHor():
    position = currentPosition()
    a = position[2][1] + 1
    labyrinth [position[0][0]][position[0][1]] = '.' #delete the first part of the rod
    labyrinth [position[2][0]][a] = '=' #add one segment to the rod in the next position 'right'
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the right
    
#private functiona: Move rod to the right if its orientation is vertical, orientation = False
def _moveRightVer():
    position = currentPosition() 
    for i in range (0,len(position)):
        labyrinth [position[i][0]][position[i][1]] = '.'
    for i in range (0,len(position)):
        position[i][1] += 1
    for i in range (0, len(position)):
        labyrinth [position[i][0]][position[i][1]] = '='
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the right in vertical orientation

    
# Public function: moves the rod to the left
def moveLeft():
    if (orientationHor()== True):
        _moveLeftHor()
    else:
        _moveLeftVer()
        
# private function Move rod to the left if its orientation is horizontal
def _moveLeftHor():
    position = currentPosition()     
    b = position[0][1] - 1
    labyrinth [position[0][0]][b] = '=' #add one segment to the rod in the next position 'left'
    labyrinth [position[2][0]] [position[2][1]] = '.' #delete the last part of the rod
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the left
    
# private function: Move rod to the left if its orientation is vertical
def _moveLeftVer():
    position = currentPosition()  #[[1, 3], [2, 3], [3, 3]]
    for i in range (0,len(position)):
        labyrinth [position[i][0]][position[i][1]] = '.'
    for i in range (0,len(position)):
        position[i][1] -= 1
    for i in range (0, len(position)):
        labyrinth [position[i][0]][position[i][1]] = '='
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the right in vertical orientation    
    

# Public function: moves the rod to bottom
def moveBottom():
    if (orientationHor()== True):
        _moveBottomHor()
    else:
        _moveBottomVer()
    
# private function: Move rod to the bottom if the orientation is horizontal
def _moveBottomHor():
    position = currentPosition()
    for i in range (0,3):
        labyrinth [position[i][0]][position[i][1]] = '.'
    for i in range (0,3):
        position[i][0] += 1
    for i in range (0, 3):
        labyrinth [position[i][0]][position[i][1]] = '='
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to bottom
    
# private function: Move rod to the bottom if the orientation is vertical
def _moveBottomVer():
    position = currentPosition() 
    a = position[2][0] + 1
    labyrinth [position[0][0]][position[0][1]] = '.' #delete the first part of the rod
    labyrinth [a][position[2][1]] = '=' #add one segment to the rod in the next position 'right'
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the right

# Public function: moves the rod to bottom
def moveTop():
    if (orientationHor()== True):
        moveTopHor()
    else:
        _moveTopVer()
    
# Move rod to the top:
def moveTopHor():
    position = currentPosition()
    for i in range (0,3):
        labyrinth [position[i][0]][position[i][1]] = '.'
    for i in range (0,3):
        position[i][0] -= 1
    for i in range (0, 3):
        labyrinth [position[i][0]][position[i][1]] = '='
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the top
    
# private function Move rod to the left if its orientation is horizontal
def _moveTopVer():
    position = currentPosition()  #[[1, 3], [2, 3], [3, 3]]    
    b = position[0][0] - 1
    labyrinth [b][position[0][1]] = '=' 
    labyrinth [position[2][0]] [position[2][1]] = '.' #delete the last part of the rod
    print(*labyrinth, sep = "\n", end = "\n\n") #show the rod after moving it to the left
    
# Spin rod from horizontal to vertical position:
def _spinHorVer():
        position = currentPosition()  
        labyrinth [position[0][0]] [position[0][1]] = '.' #delete the tail of the rod
        labyrinth [position[2][0]] [position[2][1]] = '.' #delete the head of the rod
        position[1][0] -= 1
        labyrinth [position[1][0]][position[1][1]] = '=' #spin tail
        position[1][0] += 2
        labyrinth [position[1][0]][position[1][1]] = '=' #spin head
        print(*labyrinth, sep = "\n", end = "\n\n")    #show the rod after spinning it

# Spin rod from horizontal to vertical position:
def _spinVerHor():
        position = currentPosition() 
        labyrinth [position[0][0]] [position[0][1]] = '.' #delete the tail of the rod
        labyrinth [position[2][0]] [position[2][1]] = '.' #delete the head of the rod  
        position[1][1] -= 1
        labyrinth [position[1][0]][position[1][1]] = '=' #spin tail
        position[1][1] += 2
        labyrinth [position[1][0]][position[1][1]] = '=' #spin head
        print(*labyrinth, sep = "\n", end = "\n\n")    #show the rod after spinning it
        
#Spin the rod:
def spin():
    if (orientationHor() == True):
        _spinHorVer()
    else:
        _spinVerHor()

# Get horizontal or vertical orientation:
def orientationHor():  #checks if the orientation is horizontal = True or vertical = False
    orientation = True
    position = currentPosition()     
    print (position)
    num1= position[0][0] #get first element of position list
    num2= position[1][0] #get second element of position list
    num3= position[2][0] #get third element of position list
    
    if num1 == num2 == num3:
        orientation = True
        return orientation
        print ("The orientation is horizontal.")
    else:
        orientation = False
        return orientation
        print ("The orientation is vertical.")
        

        
        
    
#reset Lab
resetLab()
 
#start
startRod()

#currentPosition
currentPosition()

#move to the bottom
moveBottomHor()
moveBottomHor()

moveRight()
moveRight()

spin()
moveRight()

moveTop()

spin()
moveTop()
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# ['=', '=', '=', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[0, 0], [0, 1], [0, 2]]
# [[0, 0], [0, 1], [0, 2]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['=', '=', '=', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[1, 0], [1, 1], [1, 2]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['=', '=', '=', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[2, 0], [2, 1], [2, 2]]
# [[2, 0], [2, 1], [2, 2]]
# [[2, 0], [2, 1], [2, 2]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '=', '=', '=', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[2, 1], [2, 2], [2, 3]]
# [[2, 1], [2, 2], [2, 3]]
# [[2, 1], [2, 2], [2, 3]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '=', '=', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[2, 2], [2, 3], [2, 4]]
# [[2, 2], [2, 3], [2, 4]]
# [[2, 2], [2, 3], [2, 4]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '=', '.', '.', '.', '.', '.']
# ['.', '.', '.', '=', '.', '.', '.', '.', '.']
# ['.', '.', '.', '=', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[1, 3], [2, 3], [3, 3]]
# [[1, 3], [2, 3], [3, 3]]
# [[1, 3], [2, 3], [3, 3]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[1, 4], [2, 4], [3, 4]]
# [[1, 4], [2, 4], [3, 4]]
# [[1, 4], [2, 4], [3, 4]]
# ['.', '.', '.', '.', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '=', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[0, 4], [1, 4], [2, 4]]
# [[0, 4], [1, 4], [2, 4]]
# [[0, 4], [1, 4], [2, 4]]
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '=', '=', '=', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
#
# [[1, 3], [1, 4], [1, 5]]
# [[1, 3], [1, 4], [1, 5]]
# [[1, 3], [1, 4], [1, 5]]
# ['.', '.', '.', '=', '=', '=', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.']
